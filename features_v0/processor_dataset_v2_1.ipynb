# %%
from analysis_functions_v2 import *
# Out:
# 2025-05-12 10:55:47.852846: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-12 10:55:47.856987: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-12 10:55:47.871854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-12 10:55:47.897042: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-12 10:55:47.905112: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12 10:55:49.165779: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# suffixes = [f"{i:03d}" for i in range(3)]
# print(suffixes)

# ids_cell = list(range(39, 40))
# print(ids_cell)
# Out:
# ['000', '001', '002']
# [39]

# %%
def process_cell_features(max_suffix=171, cell_ids=None, sat_ids=None, win_length = 50, win_shift =50,  mode=1):
    """
    Process features for either cells or satellites.
    
    Args:
        max_suffix (int): Maximum suffix number to process.
        cell_ids (list, optional): List of cell IDs to process (used in cell mode).
        sat_ids (list, optional): List of satellite IDs to process (used in satellite mode).
        mode (int): Processing mode: 1 for cell mode, 0 for satellite mode.
    
    Notes:
        - In cell mode, signals are filtered by cell_id.
        - In satellite mode, signals are filtered by sat_id using get_signals, which returns (cell_id, samples) pairs.
        - Output folders are named "cell_xxx" in cell mode and "sat_yyy" in satellite mode.
    """
    if mode == 1:
        if cell_ids is None:
            cell_ids = list(range(1, 3))  # Default cell IDs
    elif mode == 0:
        if sat_ids is None:
            sat_ids = list([2, 3, 4]) # Default Sat IDs
    else:
        raise ValueError("Invalid mode. Use 0 for satellite mode, 1 for cell mode.")

    # Define directories (adjust paths as needed)
    # data_dir = "/home/carlos/fingerprint/data"
    # features_dir = "/home/carlos/fingerprint/features_v2" 

    data_dir = "/home/carlos/Documents/fingerprint/data"
    features_dir = "/home/carlos/Documents/fingerprint/features_v2" 
    suffixes = [f"{i:03d}" for i in range(max_suffix)]
    
 
    fs = 25e6           # Sample frequency
    

    # List of satellite IDs for filtering in cell mode (kept for backward compatibility)
    ids_sat = [2, 3, 4, 5, 6, 7, 8, 9, 13, 16,
               17, 18, 22, 23, 24, 25, 26, 28, 29, 30,
               33, 36, 38, 39, 40, 42, 43, 44, 46, 48,
               49, 50, 51, 57, 65, 67, 68, 69, 71, 72,
               73, 74, 77, 78, 79, 81, 82, 85, 87, 88,
               89, 90, 92, 93, 94, 96, 99, 103, 104, 107,
               109, 110, 111, 112, 114, 115]
    
    os.makedirs(features_dir, exist_ok=True)
    feature_counter = 1
    error_list = []
    
    print(f"Starting processing in {'cell' if mode==1 else 'satellite'} mode.")
    print(f"Processing {len(suffixes)} suffixes (0 to {max_suffix-1})")
    
    error_report_path = os.path.join(features_dir, "error_report.txt")
    
    for sufix in tqdm(suffixes, desc="Processing suffixes"):
        print(f"\nProcessing suffix {sufix}...")
        try:
            # Load samples and corresponding satellite and cell data

            samples, fcs = load_samples(data_dir,sufix)
            #fc = fcs[sample]    

            ra_sat, ra_cell = load_data(data_dir, sufix)
            
            # Create a DataFrame with a multi-index (ra_sat, ra_cell)
            df = pd.DataFrame({
                'ra_sat': ra_sat,
                'ra_cell': ra_cell,
                'fcs':fcs,
                'samples': list(samples)
            })
            df.set_index(['ra_sat', 'ra_cell'], inplace=True)
            
            if mode == 1: # Process using cell_ids (cell mode)
                
                for cell in tqdm(cell_ids, desc=f"Processing cells for suffix {sufix}", leave=False):
                    cell_dir = os.path.join(features_dir, f"cell_{cell}")
                    os.makedirs(cell_dir, exist_ok=True)
                    
                    print(f"\nProcessing cell {cell}...")
                    signals_cell = get_signals_v2(df=df, cell_id=cell)
                    
                    if signals_cell:
                        sat_count = 0
                        error_count = 0
                        for idx, (sat_id, fc ,signal) in enumerate(signals_cell):
                            # Retain filtering by sat_id if it is in ids_sat
                            if sat_id in ids_sat:
                                try:
                                    print(f"- index {idx}, suffix: {sufix}, Cell {cell}, Satellite {sat_id}")
                                    
                                    # Extract I/Q components and process features
                                    i_signal = signal[:, 0]
                                    q_signal = signal[:, 1]
                                    fc = fc
                                    
                                    features = IQ_feature_processor_V3(i_signal, q_signal, win_length, win_shift, fs, fc)
                                    
                                    metadata = create_metadata_from_features_dict(
                                        features_dict     = features,
                                        sat_label         = sat_id,
                                        transmitter_label = cell,
                                        feature_counter   = feature_counter,
                                        fs                = fs,
                                        win_length        = win_length,
                                        win_shift         = win_shift,
                                        fc                = fc
                                    )

                                    
                                    feature_counter += 1
                                    sat_count += 1
                                    
                                    feature_filename = f"{metadata['Feature_Dictionary_Name']}"
                                    np.save(os.path.join(cell_dir, f"{feature_filename}.npy"), features)
                                    with open(os.path.join(cell_dir, f"{feature_filename}_metadata.json"), "w") as f:
                                        json.dump(metadata, f, indent=2)
                                    np.save(os.path.join(cell_dir, f"{feature_filename}_signal.npy"), signal)
                                except Exception as e:
                                    error_count += 1
                                    error_details = {
                                        "suffix": sufix,
                                        "cell_id": cell,
                                        "sat_id": sat_id,
                                        "df_index": idx,
                                        "error": str(e),
                                        "traceback": traceback.format_exc()
                                    }
                                    error_list.append(error_details)
                                    
                                    print(f"  ERROR processing signal: Suffix {sufix}, Cell {cell}, Satellite {sat_id}, Index {idx}")
                                    print(f"  Error details: {str(e)}")
                                    print("  Continuing to next signal...")
                        print(f"  Processed {sat_count} satellites for cell {cell}, encountered {error_count} errors")
                    else:
                        print(f"  No signals found for cell {cell}")
            
            elif mode == 0: # Process using sat_ids (satellite mode)
                
                for sat in tqdm(sat_ids, desc=f"Processing satellites for suffix {sufix}", leave=False):
                    sat_dir = os.path.join(features_dir, f"sat_{sat}")
                    os.makedirs(sat_dir, exist_ok=True)
                    
                    print(f"\nProcessing satellite {sat}...")
                    signals_sat = get_signals_v2(df=df, sat_id=sat)
                    
                    if signals_sat:
                        sat_count = 0
                        error_count = 0
                        for idx, (cell, fc, signal) in enumerate(signals_sat):
                            try:
                                print(f"- index {idx}, suffix: {sufix}, Satellite {sat}, Cell {cell}")
                                
                                i_signal = signal[:, 0]
                                q_signal = signal[:, 1]
                                
                                fc = fc
                                
                                features = IQ_feature_processor_V3(i_signal, q_signal, win_length, win_shift, fs, fc)
                                
                                metadata = create_metadata_from_features_dict(
                                    features_dict     = features,
                                    sat_label         = sat,
                                    transmitter_label = cell,
                                    feature_counter   = feature_counter,
                                    fs                = fs,
                                    win_length        = win_length,
                                    win_shift         = win_shift,
                                    fc                = fc
                                )
                                
                                feature_counter += 1
                                sat_count += 1
                                
                                feature_filename = f"{metadata['Feature_Dictionary_Name']}"
                                np.save(os.path.join(sat_dir, f"{feature_filename}.npy"), features)
                                with open(os.path.join(sat_dir, f"{feature_filename}_metadata.json"), "w") as f:
                                    json.dump(metadata, f, indent=2)
                                np.save(os.path.join(sat_dir, f"{feature_filename}_signal.npy"), signal)
                            except Exception as e:
                                error_count += 1
                                error_details = {
                                    "suffix": sufix,
                                    "cell_id": cell,
                                    "sat_id": sat,
                                    "df_index": idx,
                                    "error": str(e),
                                    "traceback": traceback.format_exc()
                                }
                                error_list.append(error_details)
                                
                                print(f"  ERROR processing signal: Suffix {sufix}, Satellite {sat}, Cell {cell}, Index {idx}")
                                print(f"  Error details: {str(e)}")
                                print("  Continuing to next signal...")
                        print(f"  Processed {sat_count} signals for satellite {sat}, encountered {error_count} errors")
                    else:
                        print(f"  No signals found for satellite {sat}")
                        
        except Exception as e:
            print(f"Error processing entire suffix {sufix}: {str(e)}")
            error_details = {
                "suffix": sufix,
                "cell_id": "ALL" if mode == 1 else "N/A",
                "sat_id": "ALL" if mode == 0 else "N/A",
                "df_index": "N/A",
                "error": str(e),
                "traceback": traceback.format_exc()
            }
            error_list.append(error_details)
            continue
    
    # Write error report
    with open(error_report_path, "w") as error_file:
        error_file.write(f"ERROR REPORT - Generated on {time.strftime('%Y-%m-%d %H:%M:%S')}\n")
        error_file.write(f"Total errors encountered: {len(error_list)}\n\n")
        
        if len(error_list) > 0:
            for i, error in enumerate(error_list, 1):
                error_file.write(f"ERROR #{i}\n")
                error_file.write(f"Suffix: {error['suffix']}\n")
                error_file.write(f"Cell ID: {error['cell_id']}\n")
                error_file.write(f"Satellite ID: {error['sat_id']}\n")
                error_file.write(f"DataFrame Index: {error['df_index']}\n")
                error_file.write(f"Error Message: {error['error']}\n")
                error_file.write(f"Traceback:\n{error['traceback']}\n")
                error_file.write("-" * 80 + "\n\n")
    
    print(f"\nProcessing complete:")
    print(f"- Total features generated: {feature_counter - 1}")
    print(f"- Total errors encountered: {len(error_list)}")
    print(f"- Error report saved to: {error_report_path}")

if __name__ == "__main__":

    # # For satellite mode (mode=0), provide sat_ids:
    # max_suffix = 171
    # sat_ids = [57, 69]  # Example: process satellite 2
    # mode = 0  # Set mode to satellite mode
    # process_cell_features(max_suffix=max_suffix, sat_ids=sat_ids, win_length = 500, win_shift =500, mode=mode)
    
    # For cell mode (mode=1), provide cell_ids:
    max_suffix = 171
    cell_ids = list(range(39, 40))
    mode = 1
    process_cell_features(max_suffix=max_suffix, cell_ids=cell_ids, win_length = 500, win_shift =500, mode=mode)
# Out:
# Starting processing in cell mode.
# Processing 171 suffixes (0 to 170)
# Processing suffixes:   0%|          | 0/171 [00:00<?, ?it/s]
# Processing suffix 000...
# Processing cell 39...
# - index 0, suffix: 000, Cell 39, Satellite 6
# - index 1, suffix: 000, Cell 39, Satellite 6
# - index 2, suffix: 000, Cell 39, Satellite 6
# - index 3, suffix: 000, Cell 39, Satellite 6
# - index 4, suffix: 000, Cell 39, Satellite 6
# - index 5, suffix: 000, Cell 39, Satellite 6
# - index 6, suffix: 000, Cell 39, Satellite 6
# - index 7, suffix: 000, Cell 39, Satellite 6
# - index 8, suffix: 000, Cell 39, Satellite 6
# - index 9, suffix: 000, Cell 39, Satellite 6
# - index 10, suffix: 000, Cell 39, Satellite 6
# - index 11, suffix: 000, Cell 39, Satellite 6
# - index 12, suffix: 000, Cell 39, Satellite 6
# - index 13, suffix: 000, Cell 39, Satellite 6
# - index 14, suffix: 000, Cell 39, Satellite 6
# - index 15, suffix: 000, Cell 39, Satellite 6
# - index 16, suffix: 000, Cell 39, Satellite 6
# - index 17, suffix: 000, Cell 39, Satellite 6
# - index 18, suffix: 000, Cell 39, Satellite 6
# - index 19, suffix: 000, Cell 39, Satellite 5
# - index 20, suffix: 000, Cell 39, Satellite 5
# - index 21, suffix: 000, Cell 39, Satellite 5
# - index 22, suffix: 000, Cell 39, Satellite 5
# - index 23, suffix: 000, Cell 39, Satellite 5
# - index 24, suffix: 000, Cell 39, Satellite 5
# - index 25, suffix: 000, Cell 39, Satellite 5
# - index 26, suffix: 000, Cell 39, Satellite 5
# - index 27, suffix: 000, Cell 39, Satellite 5
# - index 28, suffix: 000, Cell 39, Satellite 5
# - index 29, suffix: 000, Cell 39, Satellite 5
# - index 30, suffix: 000, Cell 39, Satellite 5
# - index 31, suffix: 000, Cell 39, Satellite 5
# - index 32, suffix: 000, Cell 39, Satellite 5
# - index 33, suffix: 000, Cell 39, Satellite 5
# - index 34, suffix: 000, Cell 39, Satellite 5
# - index 35, suffix: 000, Cell 39, Satellite 5
# - index 36, suffix: 000, Cell 39, Satellite 5
# - index 37, suffix: 000, Cell 39, Satellite 5
# - index 38, suffix: 000, Cell 39, Satellite 5
# - index 39, suffix: 000, Cell 39, Satellite 5
# - index 40, suffix: 000, Cell 39, Satellite 5
# - index 41, suffix: 000, Cell 39, Satellite 5
# - index 42, suffix: 000, Cell 39, Satellite 5
# - index 43, suffix: 000, Cell 39, Satellite 5
# - index 44, suffix: 000, Cell 39, Satellite 5
# - index 45, suffix: 000, Cell 39, Satellite 5
# - index 46, suffix: 000, Cell 39, Satellite 5
# - index 47, suffix: 000, Cell 39, Satellite 5
# - index 48, suffix: 000, Cell 39, Satellite 5
# - index 49, suffix: 000, Cell 39, Satellite 5
# - index 50, suffix: 000, Cell 39, Satellite 5
# - index 51, suffix: 000, Cell 39, Satellite 5
# - index 52, suffix: 000, Cell 39, Satellite 5
# - index 53, suffix: 000, Cell 39, Satellite 5
# - index 54, suffix: 000, Cell 39, Satellite 5
# - index 55, suffix: 000, Cell 39, Satellite 5
# - index 56, suffix: 000, Cell 39, Satellite 5
# - index 57, suffix: 000, Cell 39, Satellite 5
# - index 58, suffix: 000, Cell 39, Satellite 5
# - index 59, suffix: 000, Cell 39, Satellite 5
# - index 60, suffix: 000, Cell 39, Satellite 5
# - index 61, suffix: 000, Cell 39, Satellite 5
# - index 62, suffix: 000, Cell 39, Satellite 5
# - index 63, suffix: 000, Cell 39, Satellite 5
# - index 64, suffix: 000, Cell 39, Satellite 5
# - index 65, suffix: 000, Cell 39, Satellite 5
# - index 66, suffix: 000, Cell 39, Satellite 5
# - index 67, suffix: 000, Cell 39, Satellite 5
# - index 68, suffix: 000, Cell 39, Satellite 43
# - index 69, suffix: 000, Cell 39, Satellite 43
# - index 70, suffix: 000, Cell 39, Satellite 43
# - index 71, suffix: 000, Cell 39, Satellite 43
# - index 72, suffix: 000, Cell 39, Satellite 43
# - index 73, suffix: 000, Cell 39, Satellite 43
# - index 74, suffix: 000, Cell 39, Satellite 43
# - index 75, suffix: 000, Cell 39, Satellite 43
# - index 76, suffix: 000, Cell 39, Satellite 43
# - index 77, suffix: 000, Cell 39, Satellite 43
# - index 78, suffix: 000, Cell 39, Satellite 43
# - index 79, suffix: 000, Cell 39, Satellite 43
# - index 80, suffix: 000, Cell 39, Satellite 43
# - index 81, suffix: 000, Cell 39, Satellite 43
# - index 82, suffix: 000, Cell 39, Satellite 43
# - index 83, suffix: 000, Cell 39, Satellite 43
# - index 84, suffix: 000, Cell 39, Satellite 43
# - index 85, suffix: 000, Cell 39, Satellite 43
# - index 86, suffix: 000, Cell 39, Satellite 43
# - index 87, suffix: 000, Cell 39, Satellite 43
# - index 88, suffix: 000, Cell 39, Satellite 43
# - index 89, suffix: 000, Cell 39, Satellite 43
# - index 90, suffix: 000, Cell 39, Satellite 43
# - index 91, suffix: 000, Cell 39, Satellite 43
# - index 92, suffix: 000, Cell 39, Satellite 43
# - index 93, suffix: 000, Cell 39, Satellite 43
# - index 94, suffix: 000, Cell 39, Satellite 43
# - index 95, suffix: 000, Cell 39, Satellite 43
# - index 96, suffix: 000, Cell 39, Satellite 43
# - index 97, suffix: 000, Cell 39, Satellite 43
# - index 98, suffix: 000, Cell 39, Satellite 43
# - index 99, suffix: 000, Cell 39, Satellite 43
# - index 100, suffix: 000, Cell 39, Satellite 43
# - index 101, suffix: 000, Cell 39, Satellite 43
# - index 102, suffix: 000, Cell 39, Satellite 43
# - index 103, suffix: 000, Cell 39, Satellite 43
# - index 104, suffix: 000, Cell 39, Satellite 43
# - index 105, suffix: 000, Cell 39, Satellite 43
# - index 106, suffix: 000, Cell 39, Satellite 43
# - index 107, suffix: 000, Cell 39, Satellite 43
# - index 108, suffix: 000, Cell 39, Satellite 39
# - index 109, suffix: 000, Cell 39, Satellite 39
# - index 110, suffix: 000, Cell 39, Satellite 39
# - index 111, suffix: 000, Cell 39, Satellite 39
# - index 112, suffix: 000, Cell 39, Satellite 39
# - index 113, suffix: 000, Cell 39, Satellite 39
# - index 114, suffix: 000, Cell 39, Satellite 39
# - index 115, suffix: 000, Cell 39, Satellite 39
# - index 116, suffix: 000, Cell 39, Satellite 39
# - index 117, suffix: 000, Cell 39, Satellite 39
# - index 118, suffix: 000, Cell 39, Satellite 39
# - index 119, suffix: 000, Cell 39, Satellite 39
# - index 120, suffix: 000, Cell 39, Satellite 39
# - index 121, suffix: 000, Cell 39, Satellite 39
# - index 122, suffix: 000, Cell 39, Satellite 39
# - index 123, suffix: 000, Cell 39, Satellite 39
# - index 124, suffix: 000, Cell 39, Satellite 39
# - index 125, suffix: 000, Cell 39, Satellite 39
# - index 126, suffix: 000, Cell 39, Satellite 39
# - index 127, suffix: 000, Cell 39, Satellite 39
# - index 128, suffix: 000, Cell 39, Satellite 39
# - index 129, suffix: 000, Cell 39, Satellite 39
# - index 130, suffix: 000, Cell 39, Satellite 39
# - index 131, suffix: 000, Cell 39, Satellite 39
# - index 132, suffix: 000, Cell 39, Satellite 39
# - index 133, suffix: 000, Cell 39, Satellite 39
# - index 134, suffix: 000, Cell 39, Satellite 92
# - index 135, suffix: 000, Cell 39, Satellite 92
# - index 136, suffix: 000, Cell 39, Satellite 92
# - index 137, suffix: 000, Cell 39, Satellite 51
# - index 138, suffix: 000, Cell 39, Satellite 51
# - index 139, suffix: 000, Cell 39, Satellite 51
# - index 140, suffix: 000, Cell 39, Satellite 51
# - index 141, suffix: 000, Cell 39, Satellite 51
# - index 142, suffix: 000, Cell 39, Satellite 51
# - index 143, suffix: 000, Cell 39, Satellite 51
# - index 144, suffix: 000, Cell 39, Satellite 51
# - index 145, suffix: 000, Cell 39, Satellite 51
# - index 146, suffix: 000, Cell 39, Satellite 51
# - index 147, suffix: 000, Cell 39, Satellite 51
# - index 148, suffix: 000, Cell 39, Satellite 51
# - index 149, suffix: 000, Cell 39, Satellite 51
# - index 150, suffix: 000, Cell 39, Satellite 51
# - index 151, suffix: 000, Cell 39, Satellite 51
# - index 152, suffix: 000, Cell 39, Satellite 104
# - index 153, suffix: 000, Cell 39, Satellite 104
# - index 154, suffix: 000, Cell 39, Satellite 104
# - index 155, suffix: 000, Cell 39, Satellite 104
# - index 156, suffix: 000, Cell 39, Satellite 104
# - index 157, suffix: 000, Cell 39, Satellite 104
# - index 158, suffix: 000, Cell 39, Satellite 104
# - index 159, suffix: 000, Cell 39, Satellite 104
# - index 160, suffix: 000, Cell 39, Satellite 104
# - index 161, suffix: 000, Cell 39, Satellite 104
# - index 162, suffix: 000, Cell 39, Satellite 104
# - index 163, suffix: 000, Cell 39, Satellite 104
# - index 164, suffix: 000, Cell 39, Satellite 104
# - index 165, suffix: 000, Cell 39, Satellite 104
# - index 166, suffix: 000, Cell 39, Satellite 104
# - index 167, suffix: 000, Cell 39, Satellite 104
# - index 168, suffix: 000, Cell 39, Satellite 104
# - index 169, suffix: 000, Cell 39, Satellite 104
# - index 170, suffix: 000, Cell 39, Satellite 104
# - index 171, suffix: 000, Cell 39, Satellite 104
# - index 172, suffix: 000, Cell 39, Satellite 104
# - index 173, suffix: 000, Cell 39, Satellite 104
# - index 174, suffix: 000, Cell 39, Satellite 104
# - index 175, suffix: 000, Cell 39, Satellite 104
# - index 176, suffix: 000, Cell 39, Satellite 104
# - index 177, suffix: 000, Cell 39, Satellite 104
# - index 178, suffix: 000, Cell 39, Satellite 104
# - index 179, suffix: 000, Cell 39, Satellite 104
# - index 180, suffix: 000, Cell 39, Satellite 104
# - index 181, suffix: 000, Cell 39, Satellite 104
# - index 182, suffix: 000, Cell 39, Satellite 104
# - index 183, suffix: 000, Cell 39, Satellite 104
# - index 184, suffix: 000, Cell 39, Satellite 104
# - index 185, suffix: 000, Cell 39, Satellite 104
# - index 186, suffix: 000, Cell 39, Satellite 104
# - index 187, suffix: 000, Cell 39, Satellite 104
# - index 188, suffix: 000, Cell 39, Satellite 104
# - index 189, suffix: 000, Cell 39, Satellite 104
# - index 190, suffix: 000, Cell 39, Satellite 104
# - index 191, suffix: 000, Cell 39, Satellite 104
# - index 192, suffix: 000, Cell 39, Satellite 104
# - index 193, suffix: 000, Cell 39, Satellite 104
# - index 194, suffix: 000, Cell 39, Satellite 104
# - index 195, suffix: 000, Cell 39, Satellite 104
# - index 196, suffix: 000, Cell 39, Satellite 104
# - index 197, suffix: 000, Cell 39, Satellite 104
# - index 198, suffix: 000, Cell 39, Satellite 104
# - index 199, suffix: 000, Cell 39, Satellite 104
# - index 200, suffix: 000, Cell 39, Satellite 104
# - index 201, suffix: 000, Cell 39, Satellite 104
# - index 202, suffix: 000, Cell 39, Satellite 104
# - index 203, suffix: 000, Cell 39, Satellite 104
# - index 204, suffix: 000, Cell 39, Satellite 104
# - index 205, suffix: 000, Cell 39, Satellite 104
# - index 206, suffix: 000, Cell 39, Satellite 104
# - index 207, suffix: 000, Cell 39, Satellite 104
# - index 208, suffix: 000, Cell 39, Satellite 104
# - index 209, suffix: 000, Cell 39, Satellite 28
# - index 210, suffix: 000, Cell 39, Satellite 28
# - index 211, suffix: 000, Cell 39, Satellite 28
# - index 212, suffix: 000, Cell 39, Satellite 28
# - index 213, suffix: 000, Cell 39, Satellite 28
# - index 214, suffix: 000, Cell 39, Satellite 28
# - index 215, suffix: 000, Cell 39, Satellite 28
# Processing suffixes:   0%|          | 0/171 [00:05<?, ?it/s]
# - index 216, suffix: 000, Cell 39, Satellite 28
# - index 217, suffix: 000, Cell 39, Satellite 28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 245
#     243 cell_ids = list(range(39, 40))
#     244 mode = 1
# --> 245 process_cell_features(max_suffix=max_suffix, cell_ids=cell_ids, win_length = 500, win_shift =500, mode=mode)
#
# Cell In[2], line 97, in process_cell_features(max_suffix, cell_ids, sat_ids, win_length, win_shift, mode)
#      94 q_signal = signal[:, 1]
#      95 fc = fc
# ---> 97 features = IQ_feature_processor_V3(i_signal, q_signal, win_length, win_shift, fs, fc)
#      99 metadata = create_metadata_from_features_dict(
#     100     features_dict     = features,
#     101     sat_label         = sat_id,
#    (...)
#     107     fc                = fc
#     108 )
#     111 feature_counter += 1
#
# File ~/Documents/fingerprint/Satellite_Fingerprint_main/features_v0/analysis_functions_v2.py:2199, in IQ_feature_processor_V3(i_signal, q_signal, win_length, win_shift, fs, fc, pn_band)
#    2193 features["v_noise_ph"][idx] = phase_noise(win_i, win_q, fs, remove_amplitude_variation = True, polynomial_degree = 1)
#    2195 # FRACTIONAL FREQUENCY FLUCTUATIONS
#    2196 # it is computed outside the for loop
#    2197
#    2198 # IQ IMBALANCE
# -> 2199 features["v_iq_imb_epsilon_est"][idx], features["v_iq_imb_phi_est"][idx] = estimate_iq_imbalance(win_i, win_q)
#    2201 # WINDONW INDEX
#    2202 features["v_win_idx"][idx] = start
#
# File ~/Documents/fingerprint/Satellite_Fingerprint_main/features_v0/analysis_functions_v2.py:2146, in estimate_iq_imbalance(window_i, window_q)
#    2143 gain_factor_squared = var_Q / denom
#    2145 # Derive ε: ε = sqrt((1 + ε)²) - 1
# -> 2146 epsilon_est = np.sqrt(gain_factor_squared) - 1
#    2148 return epsilon_est, phi_est
#
# KeyboardInterrupt:
